# %% [markdown]
# Переменные
#
# Когда в программировании говорят о переменной, то имеют в виду именованное место для хранения данных, таких как числа, текст, списки с числами или символами и т.п. Если провести аналогию, то переменную можно рассматривать как ярлык, которым помечены определенные данные.
#
# Для создания переменных используют следующую конструкцию
#
# field='name'
# cost=200
#
# Имена переменных могут состоять из латинских букв, цифр и знака подчеркивания _, однако нельзя, чтобы переменная начиналась с цифры. Пробелы в именах переменных недопустимы, но слова разделяют знаками подчеркивания, чтобы имя переменной отражало смысл, который мы вкладываем для ее использования.
#
# total_price=120
#
# И помните, что переменные не должны совпадать с зарезервированными словами языка. Иначе компилятор не сможет понять оператор это или переменная.
# Создайте переменную name и присвойте ей ваше имя, например 'Данила' Создайте переменную age и присвойте ей значение своего возраста

# %%
name = 'Mykola'
age = 32

# %% [markdown]
# С помощью операторов мы выполняем основные арифметические операции. Символы, с помощью которых выполняются операции в языке Python, называются операторами. Основные математические операторы перечислены ниже в таблице.
# Символ 	Операция
# + 	Сложение
# - 	Вычитание
# * 	Умножение
# / 	Деление
# % 	Остаток от деления
# // 	Целочисленное деление
# ** 	Возведение в степень
#
# Пример простейшей операции:
#
# a = 5
# b = a - 3  # 2
#
# Мы произвели операцию вычитания: из числа 5 (хранится в переменной a) вычли число 3 и получили в переменной b число равное 2
# Пусть нам необходимо рассчитать услуги за потребление электричества. В переменной rate у нас находится тариф за электроэнергию 1.68, а в переменной value — значение показания счетчика, задайте для нее разумное целое число киловатт. Рассчитайте и поместите в переменную payment счет за электричество.

# %%
rate = 1.68
value = 100
payment = rate * value

# %% [markdown]
# Порядок операторов в выражении
#
# Математические операции выполняются по очереди, в зависимости от их приоритета (если не задать другую очередность с помощью скобок). Умножение и деление имеют более высокий приоритет, чем сложение и вычитание.
#
# ratio = 10
# result = 8 * (ratio + 5) - ratio ** 2
#
# Выражением называется совокупность переменных, операций, имен функций, скобок, которая может быть вычислена в соответствии с синтаксисом Python.
#
# Например, 8 * (ratio + 5) - ratio**2 — это выражение, 8 * (ratio + 5) — выражение, ratio**2 — выражение и т.д.
#
# Если возникает двоякая ситуация при чтении выражения, старайтесь их группировать вместе с помощью скобок. Возьмем, например, возведение в степень отрицательного числа -3 и возведем его в квадрат. На бумаге мы поступили бы именно так:
#
# -3 ** 2  # -9
#
# Мы получим -9, но это скорее всего не тот результат, что вы хотели. А дело в том, что в Python приоритет операции возведения в степень выше отрицания. Поэтому оборачиваем -3 в скобки и получаем ожидаемый результат.
#
# (-3) ** 2  # 9
#
# Вернёмся к предыдущей задаче. В переменной rate у нас находится тариф за электроэнергию — 1.68. Но теперь нам необходимо вести расчет дневного и ночного тарифа. Ночной тариф рассчитывается в половину дневного, т.е. rate надо поделить на 2. В переменной value_day — дневные показания счетчика, а в переменной value_night — ночные. Опять же задайте для них разумное целое число киловатт. Рассчитайте и поместите в переменную payment счет за электричество, но уже с учетом дневного и ночного тарифов.

# %%
rate = 1.68
value_day = 50
value_night = 100
payment = value_day * rate + value_night * (rate / 2)

# %% [markdown]
# Комментарии
#
# Комментарии в коде программы крайне полезные в любом языке программирования. Пока рассматриваемые примеры программы достаточно простые, но по мере роста сложности кода в программы добавляют комментарии, описывающие общий подход к решаемой задаче, — своего рода заметки, написанные на понятном языке. Эта информация бывает крайне полезной, если приходится возвращаться к своей программе через долгое время или разбираться в коде, написанном другим разработчиком. При выполнении программы компьютер игнорирует все комментарии в коде, они присутствуют там исключительно для человека.
#
# Для Python комментарий начинается с символа «решетки» (#). Интерпретатор Python игнорирует все символы, следующие в коде после # до конца строки. Пример:
#
# ratio = 10  # коэффициент коррекции
# result = 8 * (ratio + 5) - ratio ** 2
#
# Опять вернёмся к предыдущей задаче. Добавим перед вычислением переменной payment поясняющий комментарий. Закомментируйте текст 'Payment for electricity for the current month', чтобы код стал рабочим.

# %%
rate = 1.68
value_day = 358
value_night = 103
# Payment for electricity for the current month
payment = rate * value_day + rate / 2 * value_night

# %% [markdown]
# Типы данных: Строки
#
# В большинстве случаев программы определяют или собирают какой-то набор данных, а потом трансформируют их под свои потребности. Выделим основные типы данных для Python и начнем мы со строковых данных.
#
# Строка представляет собой простую последовательность символов. Любая последовательность символов, заключенная в кавычки, в Python считается строкой. Кавычки могут быть как одинарные, так и двойные.
#
# 'First string'
# "Second string"
#
# При покупке билетов нам всегда необходимо знать имя и фамилию покупателя. Объявим две строковые переменные: first_name, которая содержит имя, и переменную last_name, в которую поместим фамилию покупающего пользователя. Создайте эти две переменные и присвойте им свое имя и фамилию.

# %%
first_name = 'Mykola'
last_name = 'Prystash'

# %% [markdown]
# Строки. Конкатенация строк
#
# Самые распространенные операции, которые приходится выполнять со строковыми значениями, – это их конкатенация, определение длины строки и извлечение определенных символов и подстрок. Но этим мы займемся в модуле №5, а сейчас поговорим о конкатенации.
#
# Строки в Python можно конкатенировать при помощи оператора сложения (+). В результате строка, стоящая справа от оператора конкатенации, будет добавлена в конец строки, стоящей слева, с образованием нового строкового значения.
#
# first = 'Hello'
# second = 'world'
# sentence = first + ' ' + second + '!'  # Hello world!
#
# В переменной sentence у нас в результате окажется строка 'Hello world!'
# При покупке билетов, нам всегда необходимо знать имя и фамилию покупателя. Объявим две строковые переменные: first_name, которая содержит имя, и переменную last_name, в которую поместим фамилию покупающего пользователя. Создайте эти две переменные и присвойте им свое имя и фамилию.

# %%
first_name = 'Mykola'
last_name = 'Prystash'
full_name = first_name + ' ' + last_name
# Out:
# Mykola Prystash

# %% [markdown]
# Строки. Конкатенация строк
#
# Предыдущий пример мы могли бы оформить более красиво с помощью f-строк. Они применяются для форматирования строк и исполняются при выполнении самой программы. Фактически это шаблон, который позволяет формировать нам строку, подставляя в нее результат выполнения других выражений в необходимое нам место.
#
# От обычной строки f-строка отличается тем, что в начале строки мы ставим символ f. Интерпретатор понимает, что внутри такой строки он встретит символы фигурных скобок { }, внутри которых содержится выражение, его необходимо выполнить и результат подставить в строку.
#
# first = 'Hello'
# second = 'world'
# sentence = f"{first} {second}!"  # Hello world!
#
# В переменной sentence у нас в результате окажется строка 'Hello world!'
#
# На данные момент у нас есть три переменные: first_name, last_name и full_name
#
# Добавим переменную message, которая фактически будет прототипом шаблонного письма пользователю, купившему билет. Эту переменную мы сформируем с помощью f-строки. В переменную message мы, с помощью f-строки, поместим строку следующего содержания:
#
# "Dear <подставляем first_name>, we inform you that you have purchased a ticket to travel to the island of Mauritius. Departure June 31 of this year. Have a passport at <подставляем full_name>. We are looking forward to seeing you!"

# %%
first_name = "Stepan"
last_name = "Bandera"
full_name = first_name + " " + last_name
message = f"Dear {first_name}, we inform you that you have purchased a ticket to travel to the island of Mauritius. Departure June 31 of this year. Have a passport at {full_name}. We are looking forward to seeing you!"

# %% [markdown]
# Типы данных. Числа
#
# Пришло время чисел. В программировании они используются для ведения счета в играх, представления данных в визуализациях, хранения информации в веб-приложениях и т.д. В Python числовые данные разделены на несколько категорий по тому, как они используются. Меньше всего проблем для программиста приносит работа с целыми числами. Мы уже познакомились с основными операциями над числами в одном из первых разделов.
#
# В Python числа, имеющие дробную часть, называются вещественными (или как принято говорить «числами с плавающей точкой»). Обычно мы их используем и не особо задумываемся о поведении этих чисел, но бывают ситуации, когда числа могут вести себя неожиданно для нас
#
# a = 0.2 + 0.1  # 0.30000000000000004
#
# Данная ситуация может произойти, независимо от языка программирования, и связана она с внутренним представлением чисел в компьютерах. Поэтому сравнение вещественных чисел возможно только с определенной точностью, например, до шестого знака после запятой. Это когда сравнивают не два числа, а их разность с точностью 0.000001 - меньше она точности или нет. Если при вычислениях точность становится важной, то стоит обратить внимание на модуль decimal (https://docs.python.org/3/library/decimal.html)
#
# Переменная length содержит длину, а переменная width ширину — комнаты. Необходимо произвести расчет площади комнаты и результат поместить в переменную area. Добавьте переменную show, в которую поместите строку со следующим шаблоном: 'With width <значение ширины> and length <значение длины> of the room, its area is equal to <значение площади>'.

# %%
length = 2.75
width = 1.75
area = length * width
show = f"With width {width} and length {length} of the room, its area is equal to {area}"

# %% [markdown]
# Комплексные числа
#
# В Python встроены также и комплексные числа. Представление таких чисел происходит в виде пары значений: действительной и мнимой части, которые разделяются символом операции сложения. В завершении мнимой составной части комплексного числа обязательно ставят букву j. В следующем примере мы создаем комплексную переменную:
#
# complex = 3.14 + 1j
# print(complex)  # (3.14+1j)
#
# Чтобы получить действительную и мнимую часть чисел, отдельно необходимо использовать свойства real и image:
#
# complex = 3.14 + 1j
# print(complex.real)  # 3.14
# print(complex.imag)  # 1.0
#
# Основная область применения комплексных чисел — это научные расчеты в математике, квантовой механике, электротехнике и т.п.
#
# Необходимо выполнить сложение двух комплексных чисел (напомним, что комплексные числа поддерживают не все математические операции и не все операции сравнения).
#
# Первая переменная a равна -2 + 3j и вторая переменная b равна 4 + 2.1j. Результат необходимо поместить в переменную result.

# %%
a = -2 + 3j
b = 4 + 2.1j
result = a + b

# %% [markdown]
# Модуль math
#
# Для работы с числами в Python существует один из наиважнейших модулей math (для комплексных чисел существует отдельный модуль cmath). Этот модуль предоставляет обширный функционал для работы с числовыми данными.
#
# Чтобы добавить его в свою программу, необходимо выполнить импорт этого модуля с помощью ключевого слова import Например, чтобы извлечь квадратный корень из числа, надо использовать метод sqrt модуля math
#
# import math
#
# a = math.sqrt(100)  # 10.0
#
# Подробно работа с модулями рассматривается дальше по курсу, пока мы только пользуемся готовыми для нас методами.
#
# Необходимо вычислить корни квадратного уравнения.
#
# a · x2 + b · x + c = 0
#
# Задайте переменные коэффициенты a, b, c со значениями -2, 7, -6 соответственно
#
# Дискриминант уравнения поместите в переменную D
#
# D = b2 - 4 · a · c
#
# Корни уравнения поместите в переменные x1 и x2
#
# x1 = (-b + D0.5) / (2 · a)
#
# x2 = (-b - D0.5) / (2 · a)

# %%
import math

a = -2
b = 7
c = -6
D = pow(b, 2) - 4 * a * c
x1 = (-b + math.sqrt(D))/(2 * a)
x2 = (-b - math.sqrt(D))/(2 * a)

# %% [markdown]
# Типы данных. Boolean
#
# Булевым называется выражение, возвращающее только True или False. Такие выражения называются булевыми в честь Джорджа Буля (George Boole) (1815–1864) – пионера в области формальной логики.
#
# Для сравнения значений переменных между собой в Python есть операторы отношения:
#
#     < (меньше)
#     <= (меньше или равно)
#     > (больше)
#     >= (больше или равно)
#     == (равно)
#     != (не равно)
#
# Пример:
#
# 1 > 2 # False
#
# bool — True/False подтип целых чисел. Может принимать значения 1(соответствует True) или 0(соответствует False).
# Тип булевой часто используют, чтобы выразить некое состояние объекта. Например переменная is_active может указывать, активен аккаунт пользователя или нет. Также аккаунты пользователей часто не удаляют из базы данных, а просто устанавливают им свойство is_delete - это называют soft delete (мягкое удаление). Переменной is_active установите истинное значение, а переменной is_delete — ложное.

# %%
is_active = True
is_delete = False

# %% [markdown]
# Типы данных. Резюме
#
# Подведем краткий итог. Как видим, в Python переменные могут быть различного типа. Это означает, что переменная может хранить информацию в различных форматах:
#
#     None — пустое значение или "никакой" тип данных.
#     Числа (Numeric Type)
#     Boolean — булев (логический) тип. Является подтипом целых чисел.
#     Строки (Text Sequence Type)
#
# Из нового для нас здесь только тип None. Ним в Python обозначают пустое значение.
#
# result = None
#
# None используется тогда, когда надо явно вернуть какое-то значение или создать его (зарезервировать имя для чего-то), но по сути и смыслу никакой полезной информации пока сохранить в этом значении нельзя, даже какого рода эта информация ( строка или число, или что-то другое) пока не ясно. В таких случаях применяют None.
#
# Остальные типы мы рассмотрели уже подробно.
#
# Заведите четыре переменных разного типа и присвойте им значения соответствующего типа.
#
#     name — строковая переменная
#     age — числовая переменная
#     is_active — булева переменная
#     subscription — установить в значение None

# %%
name = 'Mykola'
age = 32
is_active = True
subscription = None

# %% [markdown]
# Приведение типов
#
# Python — это язык с динамической строгой типизацией. Это означает, что одна и та же переменная может менять свой тип по мере выполнения новых инструкций, но автоматически интерпретатор не будет менять тип данных.
#
# age = input("How old are you?")
#
# Функция input возвращает str — строку, и сравнить значение age с числом 18 — нельзя, потому что непонятно, как должно происходить такое сравнение.
#
# Но можно преобразовать тип переменной age в int при помощи встроенной функции int (функция называется точно так же, как и тип):
#
# age = input("How old are you? ")
# age = int(age)
#
# Для преобразования строк в числа с дробной частью можно использовать функцию float:
#
# pi = float('3.14')
#
# Также можно преобразовать практически любой Python объект в строку функцией str:
#
# pi_str = str(3.14)
# age_str = str(29)
#
# Для приведения других типов данных к булевому типу, используется функция bool() Функция bool() вернет False в следующих случаях
#
#     пустая строка
#     нулевое число
#     пустой список/кортеж
#
# В остальных случаях функция вернет True
#
# bool(0)  # False
# bool(1)  # True
#
# Давайте вернемся к задаче из пункта 8 про расчет площади. Ширина и высота заданы в строковом виде. Необходимо, как и раньше, рассчитать площадь, но требуется строковый тип преобразовать в численный (float) при расчете площади area. Не забудьте также добавить в переменную show строку со следующим шаблоном: 'With width <значение ширины> and length < значение длины> of the room, its area is equal to <значение площади>'.

# %%
length = "2.75"
width = "1.75"
area = float(length) * float(width)
show = f"With width {width} and length {length} of the room, its area is equal to {area}"

# %% [markdown]
# Задача: расстояние между городами
#
# Программисты часто работают с геоданными. Поработаем и мы с ними. Нам необходимо написать программу, в которой мы рассчитаем расстояние между двумя точками на поверхности Земли.
#
# Считать будем расстояние между двумя городами: Киевом и Лондоном
#
# Координаты Киева в градусах:
#
#     Широта lat1 = 50.45
#     Долгота lon1 = 30.523
#
# Координаты Лондона в градусах:
#
#     Широта lat2 = 51.5072
#     Долгота lon2 = -0.1275
#
# Радиус Земли примем 6371.01 км. Расстояние в километрах между городами с учетом искривленности планеты можно найти по следующей формуле:
#
# distance = 6371.01 · arccos(sin(lat1) · sin(lat2) + cos(lat1) · cos(lat2) · cos(lon1 - lon2))
#
# Помните, что тригонометрические функции в Python оперируют радианами. И значит величины из градусов необходимо перевести в радианы, прежде чем вычислять расстояние между точками. Для этого в модуле math есть функция radians
#
# <радианы> = math.radians(<градусы>)
#
# Также:
#
#     arccos(x) — это math.acos(x)
#     sin(x) — это math.sin(x)
#     cos(x) — это math.cos(x)
#
# Вычислите distance по указанной формуле с помощью предложенных методов модуля math.

# %%
import math

RADIUS = 6371.01

lat1 = math.radians(50.45)
lon1 = math.radians(30.523)

lat2 = math.radians(51.5072)
lon2 = math.radians(-0.1275)

distance = 6371.01 * math.acos(math.sin(lat1) * math.sin(lat2) +
                               math.cos(lat1) * math.cos(lat2) * math.cos(lon1 - lon2))
# Out:
# 7366.957924659925
# 0.18347228723435724

# %% [markdown]
# Приведение типов
#
# Мы уже работали с функцией input, она используется для чтения ввода с клавиатуры. Вызов этой функции заставляет интерпретатор остановить выполнение программы и ожидать пользовательского ввода с клавиатуры.
#
# Если пользователь нажал клавишу Enter, все введенные им ранее символы, после приглашения ввода, возвращаются функцией input, и выполнение программы продолжается.
#
# Чтобы использовать эти данные, мы присваиваем переменной возвращенное функцией input значение. Например, следующий пример считывает ввод пользователя с клавиатуры и записывает результат в переменную name.
#
# name = input("Введите ваше имя: ")
#
# Функция input всегда возвращает значение строкового типа (string). Согласно логике приложения необходимо выполнить преобразование значения в целочисленный тип или тип с плавающей запятой.
#
# В Python функции приведения типа принято использовать непосредственно в том же выражении, где запрашивается ввод с клавиатуры.
#
# count = int(input("Сколько яблок вы хотите купить? "))
#
# При заполнении анкеты на сайте нам необходимо через функцию input присвоить соответствующим переменным значения:
#
#     name - ваше имя, тип строка
#     email - ваша электронная почта, тип строка
#     age - ваш возраст, тип число int
#     height - ваш рост, тип число float
#     is_active - хотите ли вы получать уведомления от сайта, тип булевый

# %%
name = input("Your name? ")
email = input("Your email? ")
age = int(input("Your age? "))
height = float(input("Your height? "))
is_active = True

# %% [markdown]
# Задача: расчет площади
# Используя приведение типов и input, решите задачу про расчет площади. Ширина и высота заданы с помощью функции input . Необходимо, как и раньше, рассчитать площадь, но требуется строковый тип преобразовать в численный (float) при получении значения через input. Переменную show создавать не надо.

# %%
length = float(input('length? '))
width = float(input('width? '))
area = length * width
